# %%
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile
import os
import numpy as np
import pandas as pd
import wavio

# %%
# set up file paths
train_audio_path = 'audio/'
train_pict_path = 'train/'
train_map_csv = 'train_map.csv'

#test_pict_path = 'test/'
#test_audio_path = '../data/test/audio/'
#test_map_csv = '../data/test_map.csv'

# %%
# set up paths
if not os.path.exists(train_pict_path):
    os.makedirs(train_pict_path)

# get all subfolder list
subfolderlist = []
for x in os.listdir(train_audio_path):
    if os.path.isdir(train_audio_path + '/' + x):
        subfolderlist.append(x)
        if not os.path.exists(train_pict_path + '/' + x):
            os.makedirs(train_pict_path + '/' + x)

# %%
# obtain a file map with path and target for training iterators
file_target = []
for x in subfolderlist:
    temp = [['/'.join([train_audio_path[:-1], x, y]), x] for
            y in os.listdir(train_audio_path + x) if '.wav' in y]
    file_target += temp

train_file_map = pd.DataFrame(file_target, columns=['path', 'target'])
print(">>> Generated train_file_map dataframe:")
print(train_file_map.head())

# generate a test_file_map
#test_path = [[x, 0] for x in os.listdir(test_audio_path) if '.wav' in x]
#test_file_map = pd.DataFrame(test_path, columns=['path', 'target'])
#print(">>> Generated test_file_map dataframe:")
#print(test_file_map.head())
# Out:
# >>> Generated train_file_map dataframe:
#                                path target
# 0  audio/nine/c44d2a58_nohash_0.wav   nine
# 1  audio/nine/36050ef3_nohash_2.wav   nine
# 2  audio/nine/86648261_nohash_0.wav   nine
# 3  audio/nine/0e17f595_nohash_0.wav   nine
# 4  audio/nine/8dc26a15_nohash_0.wav   nine

# %%
# Function that changes .wav file into a spectrogram numbers


def log_specgram(audio, sample_rate, window_size=20, step_size=10, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    freqs, _, spec = signal.spectrogram(audio,
                                        fs=sample_rate,
                                        window='hann',
                                        nperseg=nperseg,
                                        noverlap=noverlap,
                                        detrend=False)
    return freqs, np.log(spec.T.astype(np.float32) + eps)

# %%
def wav2img(wav_path, targetdir='', figsize=(4, 4)):
    """
    takes in wave file path
    and the fig size. Default 4,4 will make images 288 x 288
    """
    fig = plt.figure(figsize=figsize)
    # use soundfile library to read in the wave files
    samplerate, test_sound = wavfile.read(wav_path)
    _, spectrogram = log_specgram(test_sound, samplerate)
    # create output path
    output_file = wav_path.split('/')[-1].split('.wav')[0]
    output_file = targetdir + '/' + output_file
    # plt.imshow(spectrogram.T, aspect='auto', origin='lower')
    plt.imsave('%s.png' % output_file, spectrogram)
    plt.close()
    return (output_file + '.png')

# %%
# generate train pictures
train_file_map['pict'] = ''
print(">>> Creating spectrograms for train .wav files")
for i in range(train_file_map.shape[0]):
    targetdir = train_pict_path + train_file_map.target[i]
    pict_path = wav2img(train_file_map.path[i], targetdir=targetdir)
    train_file_map.pict[i] = pict_path
    if (i + 1) % 500 == 0:
        print(">>> Generating %ith spectrogram..." % (i + 1))
        print(">>> File map %ith row:" % (i + 1))
        print(repr(train_file_map.iloc[i, ]))
# Out:
# >>> Creating spectrograms for train .wav files
# >>> Generating 500th spectrogram...
# >>> File map 500th row:
# path      audio/nine/c22d3f18_nohash_0.wav
# target                                nine
# pict      train/nine/c22d3f18_nohash_0.png
# Name: 499, dtype: object
# >>> Generating 1000th spectrogram...
# >>> File map 1000th row:
# path      audio/nine/7211390b_nohash_3.wav
# target                                nine
# pict      train/nine/7211390b_nohash_3.png
# Name: 999, dtype: object
# >>> Generating 1500th spectrogram...
# >>> File map 1500th row:
# path      audio/nine/56eb74ae_nohash_1.wav
# target                                nine
# pict      train/nine/56eb74ae_nohash_1.png
# Name: 1499, dtype: object
# >>> Generating 2000th spectrogram...
# >>> File map 2000th row:
# path      audio/nine/32561e9e_nohash_0.wav
# target                                nine
# pict      train/nine/32561e9e_nohash_0.png
# Name: 1999, dtype: object
# >>> Generating 2500th spectrogram...
# >>> File map 2500th row:
# path      audio/go/ab5b211a_nohash_0.wav
# target                                go
# pict      train/go/ab5b211a_nohash_0.png
# Name: 2499, dtype: object
# >>> Generating 3000th spectrogram...
# >>> File map 3000th row:
# path      audio/go/b959cd0c_nohash_2.wav
# target                                go
# pict      train/go/b959cd0c_nohash_2.png
# Name: 2999, dtype: object
# >>> Generating 3500th spectrogram...
# >>> File map 3500th row:
# path      audio/go/eb0676ec_nohash_4.wav
# target                                go
# pict      train/go/eb0676ec_nohash_4.png
# Name: 3499, dtype: object
# >>> Generating 4000th spectrogram...
# >>> File map 4000th row:
# path      audio/go/ed3c2d05_nohash_0.wav
# target                                go
# pict      train/go/ed3c2d05_nohash_0.png
# Name: 3999, dtype: object
# >>> Generating 4500th spectrogram...
# >>> File map 4500th row:
# path      audio/go/92a9c5e6_nohash_2.wav
# target                                go
# pict      train/go/92a9c5e6_nohash_2.png
# Name: 4499, dtype: object
# >>> Generating 5000th spectrogram...
# >>> File map 5000th row:
# path      audio/down/a16b3102_nohash_0.wav
# target                                down
# pict      train/down/a16b3102_nohash_0.png
# Name: 4999, dtype: object
# >>> Generating 5500th spectrogram...
# >>> File map 5500th row:
# path      audio/down/9c06a3f3_nohash_0.wav
# target                                down
# pict      train/down/9c06a3f3_nohash_0.png
# Name: 5499, dtype: object
# >>> Generating 6000th spectrogram...
# >>> File map 6000th row:
# path      audio/down/a709ddd3_nohash_0.wav
# target                                down
# pict      train/down/a709ddd3_nohash_0.png
# Name: 5999, dtype: object
# >>> Generating 6500th spectrogram...
# >>> File map 6500th row:
# path      audio/down/840c366d_nohash_0.wav
# target                                down
# pict      train/down/840c366d_nohash_0.png
# Name: 6499, dtype: object
# >>> Generating 7000th spectrogram...
# >>> File map 7000th row:
# path      audio/down/92e17cc4_nohash_0.wav
# target                                down
# pict      train/down/92e17cc4_nohash_0.png
# Name: 6999, dtype: object
# >>> Generating 7500th spectrogram...
# >>> File map 7500th row:
# path      audio/dog/656e8bb3_nohash_0.wav
# target                                dog
# pict      train/dog/656e8bb3_nohash_0.png
# Name: 7499, dtype: object
# >>> Generating 8000th spectrogram...
# >>> File map 8000th row:
# path      audio/dog/c948d727_nohash_0.wav
# target                                dog
# pict      train/dog/c948d727_nohash_0.png
# Name: 7999, dtype: object
# >>> Generating 8500th spectrogram...
# >>> File map 8500th row:
# path      audio/dog/ab353673_nohash_1.wav
# target                                dog
# pict      train/dog/ab353673_nohash_1.png
# Name: 8499, dtype: object
# >>> Generating 9000th spectrogram...
# >>> File map 9000th row:
# path      audio/two/735845ab_nohash_1.wav
# target                                two
# pict      train/two/735845ab_nohash_1.png
# Name: 8999, dtype: object
# >>> Generating 9500th spectrogram...
# >>> File map 9500th row:
# path      audio/two/6e8b9b7b_nohash_1.wav
# target                                two
# pict      train/two/6e8b9b7b_nohash_1.png
# Name: 9499, dtype: object
# >>> Generating 10000th spectrogram...
# >>> File map 10000th row:
# path      audio/two/3402e488_nohash_1.wav
# target                                two
# pict      train/two/3402e488_nohash_1.png
# Name: 9999, dtype: object
# >>> Generating 10500th spectrogram...
# >>> File map 10500th row:
# path      audio/two/af130f12_nohash_0.wav
# target                                two
# pict      train/two/af130f12_nohash_0.png
# Name: 10499, dtype: object
# >>> Generating 11000th spectrogram...
# >>> File map 11000th row:
# path      audio/two/ba59cab3_nohash_0.wav
# target                                two
# pict      train/two/ba59cab3_nohash_0.png
# Name: 10999, dtype: object
# >>> Generating 11500th spectrogram...
# >>> File map 11500th row:
# path      audio/happy/ae04cdbe_nohash_0.wav
# target                                happy
# pict      train/happy/ae04cdbe_nohash_0.png
# Name: 11499, dtype: object
# >>> Generating 12000th spectrogram...
# >>> File map 12000th row:
# path      audio/happy/89e59d18_nohash_1.wav
# target                                happy
# pict      train/happy/89e59d18_nohash_1.png
# Name: 11999, dtype: object
# >>> Generating 12500th spectrogram...
# >>> File map 12500th row:
# path      audio/happy/b36c27c2_nohash_2.wav
# target                                happy
# pict      train/happy/b36c27c2_nohash_2.png
# Name: 12499, dtype: object
# >>> Generating 13000th spectrogram...
# >>> File map 13000th row:
# path      audio/zero/fa7895de_nohash_1.wav
# target                                zero
# pict      train/zero/fa7895de_nohash_1.png
# Name: 12999, dtype: object
# >>> Generating 13500th spectrogram...
# >>> File map 13500th row:
# path      audio/zero/3c257192_nohash_3.wav
# target                                zero
# pict      train/zero/3c257192_nohash_3.png
# Name: 13499, dtype: object
# >>> Generating 14000th spectrogram...
# >>> File map 14000th row:
# path      audio/zero/65d844fc_nohash_0.wav
# target                                zero
# pict      train/zero/65d844fc_nohash_0.png
# Name: 13999, dtype: object
# >>> Generating 14500th spectrogram...
# >>> File map 14500th row:
# path      audio/zero/6727b579_nohash_2.wav
# target                                zero
# pict      train/zero/6727b579_nohash_2.png
# Name: 14499, dtype: object
# >>> Generating 15000th spectrogram...
# >>> File map 15000th row:
# path      audio/zero/ab3f0c1b_nohash_0.wav
# target                                zero
# pict      train/zero/ab3f0c1b_nohash_0.png
# Name: 14999, dtype: object
# >>> Generating 15500th spectrogram...
# >>> File map 15500th row:
# path      audio/stop/9d050657_nohash_0.wav
# target                                stop
# pict      train/stop/9d050657_nohash_0.png
# Name: 15499, dtype: object
# >>> Generating 16000th spectrogram...
# >>> File map 16000th row:
# path      audio/stop/c6ee87a7_nohash_2.wav
# target                                stop
# pict      train/stop/c6ee87a7_nohash_2.png
# Name: 15999, dtype: object
# >>> Generating 16500th spectrogram...
# >>> File map 16500th row:
# path      audio/stop/b49caed3_nohash_2.wav
# target                                stop
# pict      train/stop/b49caed3_nohash_2.png
# Name: 16499, dtype: object
# >>> Generating 17000th spectrogram...
# >>> File map 17000th row:
# path      audio/stop/88a487ce_nohash_0.wav
# target                                stop
# pict      train/stop/88a487ce_nohash_0.png
# Name: 16999, dtype: object
# >>> Generating 17500th spectrogram...
# >>> File map 17500th row:
# path      audio/stop/ba59cab3_nohash_0.wav
# target                                stop
# pict      train/stop/ba59cab3_nohash_0.png
# Name: 17499, dtype: object
# >>> Generating 18000th spectrogram...
# >>> File map 18000th row:
# path      audio/off/52e228e9_nohash_1.wav
# target                                off
# pict      train/off/52e228e9_nohash_1.png
# Name: 17999, dtype: object
# >>> Generating 18500th spectrogram...
# >>> File map 18500th row:
# path      audio/off/a24582a0_nohash_0.wav
# target                                off
# pict      train/off/a24582a0_nohash_0.png
# Name: 18499, dtype: object
# >>> Generating 19000th spectrogram...
# >>> File map 19000th row:
# path      audio/off/305776dd_nohash_0.wav
# target                                off
# pict      train/off/305776dd_nohash_0.png
# Name: 18999, dtype: object
# >>> Generating 19500th spectrogram...
# >>> File map 19500th row:
# path      audio/off/3bfd30e6_nohash_0.wav
# target                                off
# pict      train/off/3bfd30e6_nohash_0.png
# Name: 19499, dtype: object
# >>> Generating 20000th spectrogram...
# >>> File map 20000th row:
# path      audio/off/84bf12ff_nohash_1.wav
# target                                off
# pict      train/off/84bf12ff_nohash_1.png
# Name: 19999, dtype: object
# >>> Generating 20500th spectrogram...
# >>> File map 20500th row:
# path      audio/on/9f869f70_nohash_1.wav
# target                                on
# pict      train/on/9f869f70_nohash_1.png
# Name: 20499, dtype: object
# >>> Generating 21000th spectrogram...
# >>> File map 21000th row:
# path      audio/on/1ecfb537_nohash_0.wav
# target                                on
# pict      train/on/1ecfb537_nohash_0.png
# Name: 20999, dtype: object
# >>> Generating 21500th spectrogram...
# >>> File map 21500th row:
# path      audio/on/ced4e2a1_nohash_0.wav
# target                                on
# pict      train/on/ced4e2a1_nohash_0.png
# Name: 21499, dtype: object
# >>> Generating 22000th spectrogram...
# >>> File map 22000th row:
# path      audio/on/a583c5b0_nohash_1.wav
# target                                on
# pict      train/on/a583c5b0_nohash_1.png
# Name: 21999, dtype: object
# >>> Generating 22500th spectrogram...
# >>> File map 22500th row:
# path      audio/five/3f2b358d_nohash_1.wav
# target                                five
# pict      train/five/3f2b358d_nohash_1.png
# Name: 22499, dtype: object
# >>> Generating 23000th spectrogram...
# >>> File map 23000th row:
# path      audio/five/82e7204d_nohash_0.wav
# target                                five
# pict      train/five/82e7204d_nohash_0.png
# Name: 22999, dtype: object
# >>> Generating 23500th spectrogram...
# >>> File map 23500th row:
# path      audio/five/4abefdf5_nohash_1.wav
# target                                five
# pict      train/five/4abefdf5_nohash_1.png
# Name: 23499, dtype: object
# >>> Generating 24000th spectrogram...
# >>> File map 24000th row:
# path      audio/five/eb0676ec_nohash_2.wav
# target                                five
# pict      train/five/eb0676ec_nohash_2.png
# Name: 23999, dtype: object
# >>> Generating 24500th spectrogram...
# >>> File map 24500th row:
# path      audio/five/1a073312_nohash_0.wav
# target                                five
# pict      train/five/1a073312_nohash_0.png
# Name: 24499, dtype: object
# >>> Generating 25000th spectrogram...
# >>> File map 25000th row:
# path      audio/six/551e42e8_nohash_1.wav
# target                                six
# pict      train/six/551e42e8_nohash_1.png
# Name: 24999, dtype: object
# >>> Generating 25500th spectrogram...
# >>> File map 25500th row:
# path      audio/six/953fe1ad_nohash_1.wav
# target                                six
# pict      train/six/953fe1ad_nohash_1.png
# Name: 25499, dtype: object
# >>> Generating 26000th spectrogram...
# >>> File map 26000th row:
# path      audio/six/173ae793_nohash_0.wav
# target                                six
# pict      train/six/173ae793_nohash_0.png
# Name: 25999, dtype: object
# >>> Generating 26500th spectrogram...
# >>> File map 26500th row:
# path      audio/six/b00c4c53_nohash_0.wav
# target                                six
# pict      train/six/b00c4c53_nohash_0.png
# Name: 26499, dtype: object
# >>> Generating 27000th spectrogram...
# >>> File map 27000th row:
# path      audio/six/3e549219_nohash_1.wav
# target                                six
# pict      train/six/3e549219_nohash_1.png
# Name: 26999, dtype: object
# >>> Generating 27500th spectrogram...
# >>> File map 27500th row:
# path      audio/bird/2da58b32_nohash_0.wav
# target                                bird
# pict      train/bird/2da58b32_nohash_0.png
# Name: 27499, dtype: object
# >>> Generating 28000th spectrogram...
# >>> File map 28000th row:
# path      audio/bird/aac5b7c1_nohash_1.wav
# target                                bird
# pict      train/bird/aac5b7c1_nohash_1.png
# Name: 27999, dtype: object
# >>> Generating 28500th spectrogram...
# >>> File map 28500th row:
# path      audio/bird/ce9410da_nohash_1.wav
# target                                bird
# pict      train/bird/ce9410da_nohash_1.png
# Name: 28499, dtype: object
# >>> Generating 29000th spectrogram...
# >>> File map 29000th row:
# path      audio/four/1bb574f9_nohash_2.wav
# target                                four
# pict      train/four/1bb574f9_nohash_2.png
# Name: 28999, dtype: object
# >>> Generating 29500th spectrogram...
# >>> File map 29500th row:
# path      audio/four/9e2ce5e3_nohash_0.wav
# target                                four
# pict      train/four/9e2ce5e3_nohash_0.png
# Name: 29499, dtype: object
# >>> Generating 30000th spectrogram...
# >>> File map 30000th row:
# path      audio/four/7117fb6d_nohash_1.wav
# target                                four
# pict      train/four/7117fb6d_nohash_1.png
# Name: 29999, dtype: object
# >>> Generating 30500th spectrogram...
# >>> File map 30500th row:
# path      audio/four/eb67fcbc_nohash_1.wav
# target                                four
# pict      train/four/eb67fcbc_nohash_1.png
# Name: 30499, dtype: object
# >>> Generating 31000th spectrogram...
# >>> File map 31000th row:
# path      audio/four/d197e3ae_nohash_1.wav
# target                                four
# pict      train/four/d197e3ae_nohash_1.png
# Name: 30999, dtype: object
# >>> Generating 31500th spectrogram...
# >>> File map 31500th row:
# path      audio/marvin/2d3c8dcb_nohash_0.wav
# target                                marvin
# pict      train/marvin/2d3c8dcb_nohash_0.png
# Name: 31499, dtype: object
# >>> Generating 32000th spectrogram...
# >>> File map 32000th row:
# path      audio/marvin/4a4e28f1_nohash_0.wav
# target                                marvin
# pict      train/marvin/4a4e28f1_nohash_0.png
# Name: 31999, dtype: object
# >>> Generating 32500th spectrogram...
# >>> File map 32500th row:
# path      audio/marvin/af130f12_nohash_0.wav
# target                                marvin
# pict      train/marvin/af130f12_nohash_0.png
# Name: 32499, dtype: object
# >>> Generating 33000th spectrogram...
# >>> File map 33000th row:
# path      audio/marvin/ff21fb59_nohash_0.wav
# target                                marvin
# pict      train/marvin/ff21fb59_nohash_0.png
# Name: 32999, dtype: object
# >>> Generating 33500th spectrogram...
# >>> File map 33500th row:
# path      audio/tree/3efa7ec4_nohash_0.wav
# target                                tree
# pict      train/tree/3efa7ec4_nohash_0.png
# Name: 33499, dtype: object
# >>> Generating 34000th spectrogram...
# >>> File map 34000th row:
# path      audio/tree/fc28c8d8_nohash_2.wav
# target                                tree
# pict      train/tree/fc28c8d8_nohash_2.png
# Name: 33999, dtype: object
# >>> Generating 34500th spectrogram...
# >>> File map 34500th row:
# path      audio/tree/270bfa52_nohash_0.wav
# target                                tree
# pict      train/tree/270bfa52_nohash_0.png
# Name: 34499, dtype: object
# <ipython-input-7-867b750a444a>:8: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   samplerate, test_sound = wavfile.read(wav_path)
# >>> Generating 35000th spectrogram...
# >>> File map 35000th row:
# path      audio/right/8e05039f_nohash_3.wav
# target                                right
# pict      train/right/8e05039f_nohash_3.png
# Name: 34999, dtype: object
# >>> Generating 35500th spectrogram...
# >>> File map 35500th row:
# path      audio/right/eee5e541_nohash_1.wav
# target                                right
# pict      train/right/eee5e541_nohash_1.png
# Name: 35499, dtype: object
# >>> Generating 36000th spectrogram...
# >>> File map 36000th row:
# path      audio/right/1e4064b8_nohash_2.wav
# target                                right
# pict      train/right/1e4064b8_nohash_2.png
# Name: 35999, dtype: object
# >>> Generating 36500th spectrogram...
# >>> File map 36500th row:
# path      audio/right/becd5a53_nohash_0.wav
# target                                right
# pict      train/right/becd5a53_nohash_0.png
# Name: 36499, dtype: object
# >>> Generating 37000th spectrogram...
# >>> File map 37000th row:
# path      audio/right/7ea032f3_nohash_4.wav
# target                                right
# pict      train/right/7ea032f3_nohash_4.png
# Name: 36999, dtype: object
# >>> Generating 37500th spectrogram...
# >>> File map 37500th row:
# path      audio/bed/422d3197_nohash_0.wav
# target                                bed
# pict      train/bed/422d3197_nohash_0.png
# Name: 37499, dtype: object
# >>> Generating 38000th spectrogram...
# >>> File map 38000th row:
# path      audio/bed/bc065a17_nohash_2.wav
# target                                bed
# pict      train/bed/bc065a17_nohash_2.png
# Name: 37999, dtype: object
# >>> Generating 38500th spectrogram...
# >>> File map 38500th row:
# path      audio/bed/c4f875a9_nohash_1.wav
# target                                bed
# pict      train/bed/c4f875a9_nohash_1.png
# Name: 38499, dtype: object
# >>> Generating 39000th spectrogram...
# >>> File map 39000th row:
# path      audio/house/070b49af_nohash_1.wav
# target                                house
# pict      train/house/070b49af_nohash_1.png
# Name: 38999, dtype: object
# >>> Generating 39500th spectrogram...
# >>> File map 39500th row:
# path      audio/house/ec7d1151_nohash_0.wav
# target                                house
# pict      train/house/ec7d1151_nohash_0.png
# Name: 39499, dtype: object
# >>> Generating 40000th spectrogram...
# >>> File map 40000th row:
# path      audio/house/0f3f64d5_nohash_1.wav
# target                                house
# pict      train/house/0f3f64d5_nohash_1.png
# Name: 39999, dtype: object
# >>> Generating 40500th spectrogram...
# >>> File map 40500th row:
# path      audio/house/d7a58714_nohash_0.wav
# target                                house
# pict      train/house/d7a58714_nohash_0.png
# Name: 40499, dtype: object
# >>> Generating 41000th spectrogram...
# >>> File map 41000th row:
# path      audio/eight/c518d1b1_nohash_1.wav
# target                                eight
# pict      train/eight/c518d1b1_nohash_1.png
# Name: 40999, dtype: object
# >>> Generating 41500th spectrogram...
# >>> File map 41500th row:
# path      audio/eight/a759efbc_nohash_0.wav
# target                                eight
# pict      train/eight/a759efbc_nohash_0.png
# Name: 41499, dtype: object
# >>> Generating 42000th spectrogram...
# >>> File map 42000th row:
# path      audio/eight/1338a799_nohash_0.wav
# target                                eight
# pict      train/eight/1338a799_nohash_0.png
# Name: 41999, dtype: object
# >>> Generating 42500th spectrogram...
# >>> File map 42500th row:
# path      audio/eight/8281a2a8_nohash_0.wav
# target                                eight
# pict      train/eight/8281a2a8_nohash_0.png
# Name: 42499, dtype: object
# >>> Generating 43000th spectrogram...
# >>> File map 43000th row:
# path      audio/wow/b575b5fb_nohash_0.wav
# target                                wow
# pict      train/wow/b575b5fb_nohash_0.png
# Name: 42999, dtype: object
# >>> Generating 43500th spectrogram...
# >>> File map 43500th row:
# path      audio/wow/fe5c4a7a_nohash_1.wav
# target                                wow
# pict      train/wow/fe5c4a7a_nohash_1.png
# Name: 43499, dtype: object
# >>> Generating 44000th spectrogram...
# >>> File map 44000th row:
# path      audio/wow/c38720cb_nohash_0.wav
# target                                wow
# pict      train/wow/c38720cb_nohash_0.png
# Name: 43999, dtype: object
# >>> Generating 44500th spectrogram...
# >>> File map 44500th row:
# path      audio/wow/44715c1c_nohash_0.wav
# target                                wow
# pict      train/wow/44715c1c_nohash_0.png
# Name: 44499, dtype: object
# >>> Generating 45000th spectrogram...
# >>> File map 45000th row:
# path      audio/seven/4e8c5516_nohash_0.wav
# target                                seven
# pict      train/seven/4e8c5516_nohash_0.png
# Name: 44999, dtype: object
# >>> Generating 45500th spectrogram...
# >>> File map 45500th row:
# path      audio/seven/39a6b995_nohash_1.wav
# target                                seven
# pict      train/seven/39a6b995_nohash_1.png
# Name: 45499, dtype: object
# >>> Generating 46000th spectrogram...
# >>> File map 46000th row:
# path      audio/seven/ee07dcb9_nohash_0.wav
# target                                seven
# pict      train/seven/ee07dcb9_nohash_0.png
# Name: 45999, dtype: object
# >>> Generating 46500th spectrogram...
# >>> File map 46500th row:
# path      audio/seven/8012c69d_nohash_1.wav
# target                                seven
# pict      train/seven/8012c69d_nohash_1.png
# Name: 46499, dtype: object
# >>> Generating 47000th spectrogram...
# >>> File map 47000th row:
# path      audio/seven/59c3a7f2_nohash_0.wav
# target                                seven
# pict      train/seven/59c3a7f2_nohash_0.png
# Name: 46999, dtype: object
# >>> Generating 47500th spectrogram...
# >>> File map 47500th row:
# path      audio/up/c93d5e22_nohash_2.wav
# target                                up
# pict      train/up/c93d5e22_nohash_2.png
# Name: 47499, dtype: object
# >>> Generating 48000th spectrogram...
# >>> File map 48000th row:
# path      audio/up/742d6431_nohash_1.wav
# target                                up
# pict      train/up/742d6431_nohash_1.png
# Name: 47999, dtype: object
# >>> Generating 48500th spectrogram...
# >>> File map 48500th row:
# path      audio/up/571c044e_nohash_1.wav
# target                                up
# pict      train/up/571c044e_nohash_1.png
# Name: 48499, dtype: object
# >>> Generating 49000th spectrogram...
# >>> File map 49000th row:
# path      audio/up/4f781a59_nohash_1.wav
# target                                up
# pict      train/up/4f781a59_nohash_1.png
# Name: 48999, dtype: object
# >>> Generating 49500th spectrogram...
# >>> File map 49500th row:
# path      audio/no/5fc3ed24_nohash_0.wav
# target                                no
# pict      train/no/5fc3ed24_nohash_0.png
# Name: 49499, dtype: object
# >>> Generating 50000th spectrogram...
# >>> File map 50000th row:
# path      audio/no/3f2b358d_nohash_2.wav
# target                                no
# pict      train/no/3f2b358d_nohash_2.png
# Name: 49999, dtype: object
# >>> Generating 50500th spectrogram...
# >>> File map 50500th row:
# path      audio/no/c634a189_nohash_2.wav
# target                                no
# pict      train/no/c634a189_nohash_2.png
# Name: 50499, dtype: object
# >>> Generating 51000th spectrogram...
# >>> File map 51000th row:
# path      audio/no/e41a903b_nohash_3.wav
# target                                no
# pict      train/no/e41a903b_nohash_3.png
# Name: 50999, dtype: object
# >>> Generating 51500th spectrogram...
# >>> File map 51500th row:
# path      audio/no/b7a0754f_nohash_4.wav
# target                                no
# pict      train/no/b7a0754f_nohash_4.png
# Name: 51499, dtype: object
# >>> Generating 52000th spectrogram...
# >>> File map 52000th row:
# path      audio/three/60472d26_nohash_0.wav
# target                                three
# pict      train/three/60472d26_nohash_0.png
# Name: 51999, dtype: object
# >>> Generating 52500th spectrogram...
# >>> File map 52500th row:
# path      audio/three/3cdecb0b_nohash_0.wav
# target                                three
# pict      train/three/3cdecb0b_nohash_0.png
# Name: 52499, dtype: object
# >>> Generating 53000th spectrogram...
# >>> File map 53000th row:
# path      audio/three/dfb6450b_nohash_0.wav
# target                                three
# pict      train/three/dfb6450b_nohash_0.png
# Name: 52999, dtype: object
# >>> Generating 53500th spectrogram...
# >>> File map 53500th row:
# path      audio/three/e5d2e09d_nohash_0.wav
# target                                three
# pict      train/three/e5d2e09d_nohash_0.png
# Name: 53499, dtype: object
# >>> Generating 54000th spectrogram...
# >>> File map 54000th row:
# path      audio/three/528f9242_nohash_0.wav
# target                                three
# pict      train/three/528f9242_nohash_0.png
# Name: 53999, dtype: object
# >>> Generating 54500th spectrogram...
# >>> File map 54500th row:
# path      audio/left/f852895b_nohash_1.wav
# target                                left
# pict      train/left/f852895b_nohash_1.png
# Name: 54499, dtype: object
# >>> Generating 55000th spectrogram...
# >>> File map 55000th row:
# path      audio/left/106a6183_nohash_3.wav
# target                                left
# pict      train/left/106a6183_nohash_3.png
# Name: 54999, dtype: object
# >>> Generating 55500th spectrogram...
# >>> File map 55500th row:
# path      audio/left/ef2578c0_nohash_1.wav
# target                                left
# pict      train/left/ef2578c0_nohash_1.png
# Name: 55499, dtype: object
# >>> Generating 56000th spectrogram...
# >>> File map 56000th row:
# path      audio/left/b59fa113_nohash_0.wav
# target                                left
# pict      train/left/b59fa113_nohash_0.png
# Name: 55999, dtype: object
# >>> Generating 56500th spectrogram...
# >>> File map 56500th row:
# path      audio/left/0a7c2a8d_nohash_0.wav
# target                                left
# pict      train/left/0a7c2a8d_nohash_0.png
# Name: 56499, dtype: object
# >>> Generating 57000th spectrogram...
# >>> File map 57000th row:
# path      audio/one/db72a474_nohash_0.wav
# target                                one
# pict      train/one/db72a474_nohash_0.png
# Name: 56999, dtype: object
# >>> Generating 57500th spectrogram...
# >>> File map 57500th row:
# path      audio/one/f292725f_nohash_0.wav
# target                                one
# pict      train/one/f292725f_nohash_0.png
# Name: 57499, dtype: object
# >>> Generating 58000th spectrogram...
# >>> File map 58000th row:
# path      audio/one/b4aa9fef_nohash_3.wav
# target                                one
# pict      train/one/b4aa9fef_nohash_3.png
# Name: 57999, dtype: object
# >>> Generating 58500th spectrogram...
# >>> File map 58500th row:
# path      audio/one/4b39347d_nohash_1.wav
# target                                one
# pict      train/one/4b39347d_nohash_1.png
# Name: 58499, dtype: object
# >>> Generating 59000th spectrogram...
# >>> File map 59000th row:
# path      audio/sheila/6f5b4d3d_nohash_0.wav
# target                                sheila
# pict      train/sheila/6f5b4d3d_nohash_0.png
# Name: 58999, dtype: object
# >>> Generating 59500th spectrogram...
# >>> File map 59500th row:
# path      audio/sheila/682e1687_nohash_0.wav
# target                                sheila
# pict      train/sheila/682e1687_nohash_0.png
# Name: 59499, dtype: object
# >>> Generating 60000th spectrogram...
# >>> File map 60000th row:
# path      audio/sheila/06076b6b_nohash_0.wav
# target                                sheila
# pict      train/sheila/06076b6b_nohash_0.png
# Name: 59999, dtype: object
# >>> Generating 60500th spectrogram...
# >>> File map 60500th row:
# path      audio/sheila/44260689_nohash_0.wav
# target                                sheila
# pict      train/sheila/44260689_nohash_0.png
# Name: 60499, dtype: object
# >>> Generating 61000th spectrogram...
# >>> File map 61000th row:
# path      audio/cat/28ef2a01_nohash_0.wav
# target                                cat
# pict      train/cat/28ef2a01_nohash_0.png
# Name: 60999, dtype: object
# >>> Generating 61500th spectrogram...
# >>> File map 61500th row:
# path      audio/cat/c2df23b2_nohash_0.wav
# target                                cat
# pict      train/cat/c2df23b2_nohash_0.png
# Name: 61499, dtype: object
# >>> Generating 62000th spectrogram...
# >>> File map 62000th row:
# path      audio/cat/2c7c33e8_nohash_0.wav
# target                                cat
# pict      train/cat/2c7c33e8_nohash_0.png
# Name: 61999, dtype: object
# >>> Generating 62500th spectrogram...
# >>> File map 62500th row:
# path      audio/yes/b9515bf3_nohash_4.wav
# target                                yes
# pict      train/yes/b9515bf3_nohash_4.png
# Name: 62499, dtype: object
# >>> Generating 63000th spectrogram...
# >>> File map 63000th row:
# path      audio/yes/126a31d2_nohash_0.wav
# target                                yes
# pict      train/yes/126a31d2_nohash_0.png
# Name: 62999, dtype: object
# >>> Generating 63500th spectrogram...
# >>> File map 63500th row:
# path      audio/yes/6c429c7b_nohash_3.wav
# target                                yes
# pict      train/yes/6c429c7b_nohash_3.png
# Name: 63499, dtype: object
# >>> Generating 64000th spectrogram...
# >>> File map 64000th row:
# path      audio/yes/ec74a8a5_nohash_1.wav
# target                                yes
# pict      train/yes/ec74a8a5_nohash_1.png
# Name: 63999, dtype: object
# >>> Generating 64500th spectrogram...
# >>> File map 64500th row:
# path      audio/yes/9db2bfe9_nohash_4.wav
# target                                yes
# pict      train/yes/9db2bfe9_nohash_4.png
# Name: 64499, dtype: object

# %%
i = 0
targetdir = train_pict_path + train_file_map.target[i]
targetdir
pict_path = wav2img(train_file_map.path[i], targetdir=targetdir)
pict_path
train_file_map.pict[i] = pict_path
print(repr(train_file_map.iloc[i,]))
# Out:
# path      audio/nine/c44d2a58_nohash_0.wav
# target                                nine
# pict      train/nine/c44d2a58_nohash_0.png
# Name: 0, dtype: object

# %%
# saving train map file
train_file_map.to_csv(train_map_csv, index=True)
