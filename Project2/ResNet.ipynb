# %%
# import the needed modules

from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
# Training parameters
batch_size = 32  
epochs = 200
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# %%
# Model version
version = 1
n = 3
# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# %%
# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 1:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 16)   448         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 32, 32, 16)   64          conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 16)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 16)   2320        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 16)   64          conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 16)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 16)   2320        activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 16)   64          conv2d_44[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 32, 32, 16)   0           activation_38[0][0]
#                                                                  batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 16)   0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 16)   2320        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 32, 16)   64          conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 16)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 16)   2320        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 32, 16)   64          conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 16)   0           activation_40[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 16)   0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 16)   2320        activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 32, 16)   64          conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 16)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 16)   2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 32, 32, 16)   64          conv2d_48[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 16)   0           activation_42[0][0]
#                                                                  batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 32, 16)   0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 16, 16, 32)   4640        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 16, 16, 32)   128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 16, 16, 32)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 32)   9248        activation_45[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 16, 16, 32)   544         activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 16, 32)   128         conv2d_50[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 16, 16, 32)   0           conv2d_51[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 16, 16, 32)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 16, 16, 32)   9248        activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 16, 16, 32)   128         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 16, 16, 32)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 16, 16, 32)   9248        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 32)   128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 32)   0           activation_46[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 32)   0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 16, 16, 32)   9248        activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 16, 32)   128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 32)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 16, 16, 32)   9248        activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 16, 16, 32)   128         conv2d_55[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 32)   0           activation_48[0][0]
#                                                                  batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 16, 16, 32)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 64)     18496       activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 8, 8, 64)     256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8, 8, 64)     0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 64)     36928       activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 8, 8, 64)     2112        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 64)     256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 8, 8, 64)     0           conv2d_58[0][0]
#                                                                  batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 64)     0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 8, 8, 64)     36928       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 64)     256         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 64)     0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 8, 8, 64)     36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 64)     256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 8, 8, 64)     0           activation_52[0][0]
#                                                                  batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 64)     0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 8, 8, 64)     36928       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8, 8, 64)     256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 64)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 8, 8, 64)     36928       activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 8, 8, 64)     256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 8, 8, 64)     0           activation_54[0][0]
#                                                                  batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 8, 8, 64)     0           add_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 64)     0           activation_56[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 64)           0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           650         flatten_2[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True, save_weights_only=False, mode='max', save_freq='epoch')

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)
# Out:
# Using real-time data augmentation.

# %%
# Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

from numpy.random import seed
seed(123)

    # Fit the model on the batches generated by datagen.flow().
history=model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 43s 26ms/step - loss: 1.8204 - accuracy: 0.4053 - val_loss: 1.5299 - val_accuracy: 0.5251
#
# Epoch 00001: val_accuracy improved from -inf to 0.52510, saving model to /content/saved_models/cifar10_ResNet20v1_model.001.h5
# Epoch 2/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.2282 - accuracy: 0.6152 - val_loss: 1.5173 - val_accuracy: 0.5634
#
# Epoch 00002: val_accuracy improved from 0.52510 to 0.56340, saving model to /content/saved_models/cifar10_ResNet20v1_model.002.h5
# Epoch 3/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.0571 - accuracy: 0.6858 - val_loss: 1.1482 - val_accuracy: 0.6510
#
# Epoch 00003: val_accuracy improved from 0.56340 to 0.65100, saving model to /content/saved_models/cifar10_ResNet20v1_model.003.h5
# Epoch 4/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.9471 - accuracy: 0.7237 - val_loss: 1.2383 - val_accuracy: 0.6616
#
# Epoch 00004: val_accuracy improved from 0.65100 to 0.66160, saving model to /content/saved_models/cifar10_ResNet20v1_model.004.h5
# Epoch 5/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.8824 - accuracy: 0.7534 - val_loss: 1.0535 - val_accuracy: 0.7010
#
# Epoch 00005: val_accuracy improved from 0.66160 to 0.70100, saving model to /content/saved_models/cifar10_ResNet20v1_model.005.h5
# Epoch 6/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.8369 - accuracy: 0.7688 - val_loss: 0.8623 - val_accuracy: 0.7677
#
# Epoch 00006: val_accuracy improved from 0.70100 to 0.76770, saving model to /content/saved_models/cifar10_ResNet20v1_model.006.h5
# Epoch 7/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.8007 - accuracy: 0.7821 - val_loss: 1.2656 - val_accuracy: 0.6739
#
# Epoch 00007: val_accuracy did not improve from 0.76770
# Epoch 8/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7572 - accuracy: 0.8016 - val_loss: 1.1721 - val_accuracy: 0.6821
#
# Epoch 00008: val_accuracy did not improve from 0.76770
# Epoch 9/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7317 - accuracy: 0.8081 - val_loss: 0.8584 - val_accuracy: 0.7675
#
# Epoch 00009: val_accuracy did not improve from 0.76770
# Epoch 10/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7101 - accuracy: 0.8156 - val_loss: 0.8850 - val_accuracy: 0.7747
#
# Epoch 00010: val_accuracy improved from 0.76770 to 0.77470, saving model to /content/saved_models/cifar10_ResNet20v1_model.010.h5
# Epoch 11/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.6952 - accuracy: 0.8214 - val_loss: 0.8060 - val_accuracy: 0.7952
#
# Epoch 00011: val_accuracy improved from 0.77470 to 0.79520, saving model to /content/saved_models/cifar10_ResNet20v1_model.011.h5
# Epoch 12/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6734 - accuracy: 0.8310 - val_loss: 0.8273 - val_accuracy: 0.7971
#
# Epoch 00012: val_accuracy improved from 0.79520 to 0.79710, saving model to /content/saved_models/cifar10_ResNet20v1_model.012.h5
# Epoch 13/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.6607 - accuracy: 0.8376 - val_loss: 0.8164 - val_accuracy: 0.7890
#
# Epoch 00013: val_accuracy did not improve from 0.79710
# Epoch 14/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.6508 - accuracy: 0.8398 - val_loss: 0.7782 - val_accuracy: 0.8045
#
# Epoch 00014: val_accuracy improved from 0.79710 to 0.80450, saving model to /content/saved_models/cifar10_ResNet20v1_model.014.h5
# Epoch 15/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6411 - accuracy: 0.8449 - val_loss: 0.8291 - val_accuracy: 0.7898
#
# Epoch 00015: val_accuracy did not improve from 0.80450
# Epoch 16/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.6403 - accuracy: 0.8438 - val_loss: 0.8324 - val_accuracy: 0.8012
#
# Epoch 00016: val_accuracy did not improve from 0.80450
# Epoch 17/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6206 - accuracy: 0.8517 - val_loss: 0.7238 - val_accuracy: 0.8178
#
# Epoch 00017: val_accuracy improved from 0.80450 to 0.81780, saving model to /content/saved_models/cifar10_ResNet20v1_model.017.h5
# Epoch 18/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6048 - accuracy: 0.8588 - val_loss: 0.8523 - val_accuracy: 0.7887
#
# Epoch 00018: val_accuracy did not improve from 0.81780
# Epoch 19/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6071 - accuracy: 0.8582 - val_loss: 0.8685 - val_accuracy: 0.7918
#
# Epoch 00019: val_accuracy did not improve from 0.81780
# Epoch 20/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6045 - accuracy: 0.8603 - val_loss: 0.7840 - val_accuracy: 0.8127
#
# Epoch 00020: val_accuracy did not improve from 0.81780
# Epoch 21/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5857 - accuracy: 0.8658 - val_loss: 0.9240 - val_accuracy: 0.7789
#
# Epoch 00021: val_accuracy did not improve from 0.81780
# Epoch 22/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5880 - accuracy: 0.8651 - val_loss: 0.6975 - val_accuracy: 0.8328
#
# Epoch 00022: val_accuracy improved from 0.81780 to 0.83280, saving model to /content/saved_models/cifar10_ResNet20v1_model.022.h5
# Epoch 23/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5865 - accuracy: 0.8649 - val_loss: 0.6985 - val_accuracy: 0.8316
#
# Epoch 00023: val_accuracy did not improve from 0.83280
# Epoch 24/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5810 - accuracy: 0.8669 - val_loss: 0.9085 - val_accuracy: 0.7892
#
# Epoch 00024: val_accuracy did not improve from 0.83280
# Epoch 25/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5784 - accuracy: 0.8691 - val_loss: 0.7145 - val_accuracy: 0.8327
#
# Epoch 00025: val_accuracy did not improve from 0.83280
# Epoch 26/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5677 - accuracy: 0.8726 - val_loss: 0.8059 - val_accuracy: 0.8037
#
# Epoch 00026: val_accuracy did not improve from 0.83280
# Epoch 27/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5639 - accuracy: 0.8753 - val_loss: 0.7808 - val_accuracy: 0.8156
#
# Epoch 00027: val_accuracy did not improve from 0.83280
# Epoch 28/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5636 - accuracy: 0.8754 - val_loss: 0.8350 - val_accuracy: 0.7975
#
# Epoch 00028: val_accuracy did not improve from 0.83280
# Epoch 29/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5649 - accuracy: 0.8731 - val_loss: 0.7923 - val_accuracy: 0.8098
#
# Epoch 00029: val_accuracy did not improve from 0.83280
# Epoch 30/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5530 - accuracy: 0.8783 - val_loss: 0.6628 - val_accuracy: 0.8418
#
# Epoch 00030: val_accuracy improved from 0.83280 to 0.84180, saving model to /content/saved_models/cifar10_ResNet20v1_model.030.h5
# Epoch 31/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5594 - accuracy: 0.8774 - val_loss: 0.6876 - val_accuracy: 0.8397
#
# Epoch 00031: val_accuracy did not improve from 0.84180
# Epoch 32/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5528 - accuracy: 0.8809 - val_loss: 0.7759 - val_accuracy: 0.8111
#
# Epoch 00032: val_accuracy did not improve from 0.84180
# Epoch 33/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5455 - accuracy: 0.8829 - val_loss: 0.7516 - val_accuracy: 0.8192
#
# Epoch 00033: val_accuracy did not improve from 0.84180
# Epoch 34/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5367 - accuracy: 0.8844 - val_loss: 0.7018 - val_accuracy: 0.8365
#
# Epoch 00034: val_accuracy did not improve from 0.84180
# Epoch 35/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5435 - accuracy: 0.8828 - val_loss: 0.6667 - val_accuracy: 0.8437
#
# Epoch 00035: val_accuracy improved from 0.84180 to 0.84370, saving model to /content/saved_models/cifar10_ResNet20v1_model.035.h5
# Epoch 36/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5387 - accuracy: 0.8857 - val_loss: 0.6989 - val_accuracy: 0.8394
#
# Epoch 00036: val_accuracy did not improve from 0.84370
# Epoch 37/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5447 - accuracy: 0.8823 - val_loss: 0.6497 - val_accuracy: 0.8461
#
# Epoch 00037: val_accuracy improved from 0.84370 to 0.84610, saving model to /content/saved_models/cifar10_ResNet20v1_model.037.h5
# Epoch 38/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5396 - accuracy: 0.8851 - val_loss: 0.6632 - val_accuracy: 0.8480
#
# Epoch 00038: val_accuracy improved from 0.84610 to 0.84800, saving model to /content/saved_models/cifar10_ResNet20v1_model.038.h5
# Epoch 39/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5336 - accuracy: 0.8844 - val_loss: 0.8773 - val_accuracy: 0.7949
#
# Epoch 00039: val_accuracy did not improve from 0.84800
# Epoch 40/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5329 - accuracy: 0.8884 - val_loss: 0.8435 - val_accuracy: 0.8008
#
# Epoch 00040: val_accuracy did not improve from 0.84800
# Epoch 41/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5253 - accuracy: 0.8904 - val_loss: 0.7831 - val_accuracy: 0.8174
#
# Epoch 00041: val_accuracy did not improve from 0.84800
# Epoch 42/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5325 - accuracy: 0.8872 - val_loss: 0.6590 - val_accuracy: 0.8467
#
# Epoch 00042: val_accuracy did not improve from 0.84800
# Epoch 43/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5236 - accuracy: 0.8901 - val_loss: 0.7739 - val_accuracy: 0.8314
#
# Epoch 00043: val_accuracy did not improve from 0.84800
# Epoch 44/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5201 - accuracy: 0.8914 - val_loss: 0.7514 - val_accuracy: 0.8205
#
# Epoch 00044: val_accuracy did not improve from 0.84800
# Epoch 45/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5222 - accuracy: 0.8889 - val_loss: 0.8712 - val_accuracy: 0.8113
#
# Epoch 00045: val_accuracy did not improve from 0.84800
# Epoch 46/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5207 - accuracy: 0.8928 - val_loss: 0.7228 - val_accuracy: 0.8420
#
# Epoch 00046: val_accuracy did not improve from 0.84800
# Epoch 47/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5241 - accuracy: 0.8907 - val_loss: 0.7079 - val_accuracy: 0.8416
#
# Epoch 00047: val_accuracy did not improve from 0.84800
# Epoch 48/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5182 - accuracy: 0.8933 - val_loss: 0.7555 - val_accuracy: 0.8328
#
# Epoch 00048: val_accuracy did not improve from 0.84800
# Epoch 49/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5175 - accuracy: 0.8929 - val_loss: 0.6256 - val_accuracy: 0.8607
#
# Epoch 00049: val_accuracy improved from 0.84800 to 0.86070, saving model to /content/saved_models/cifar10_ResNet20v1_model.049.h5
# Epoch 50/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5222 - accuracy: 0.8914 - val_loss: 0.6732 - val_accuracy: 0.8425
#
# Epoch 00050: val_accuracy did not improve from 0.86070
# Epoch 51/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5146 - accuracy: 0.8934 - val_loss: 0.6995 - val_accuracy: 0.8342
#
# Epoch 00051: val_accuracy did not improve from 0.86070
# Epoch 52/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5159 - accuracy: 0.8920 - val_loss: 0.8044 - val_accuracy: 0.8173
#
# Epoch 00052: val_accuracy did not improve from 0.86070
# Epoch 53/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5090 - accuracy: 0.8975 - val_loss: 0.6723 - val_accuracy: 0.8468
#
# Epoch 00053: val_accuracy did not improve from 0.86070
# Epoch 54/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5079 - accuracy: 0.8959 - val_loss: 0.7054 - val_accuracy: 0.8342
#
# Epoch 00054: val_accuracy did not improve from 0.86070
# Epoch 55/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5155 - accuracy: 0.8959 - val_loss: 0.6365 - val_accuracy: 0.8579
#
# Epoch 00055: val_accuracy did not improve from 0.86070
# Epoch 56/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5004 - accuracy: 0.8989 - val_loss: 0.6534 - val_accuracy: 0.8557
#
# Epoch 00056: val_accuracy did not improve from 0.86070
# Epoch 57/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5054 - accuracy: 0.8948 - val_loss: 0.7279 - val_accuracy: 0.8377
#
# Epoch 00057: val_accuracy did not improve from 0.86070
# Epoch 58/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5056 - accuracy: 0.8974 - val_loss: 0.7216 - val_accuracy: 0.8389
#
# Epoch 00058: val_accuracy did not improve from 0.86070
# Epoch 59/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5034 - accuracy: 0.8979 - val_loss: 0.7868 - val_accuracy: 0.8198
#
# Epoch 00059: val_accuracy did not improve from 0.86070
# Epoch 60/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5113 - accuracy: 0.8938 - val_loss: 0.7410 - val_accuracy: 0.8286
#
# Epoch 00060: val_accuracy did not improve from 0.86070
# Epoch 61/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5037 - accuracy: 0.8971 - val_loss: 0.6546 - val_accuracy: 0.8523
#
# Epoch 00061: val_accuracy did not improve from 0.86070
# Epoch 62/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5033 - accuracy: 0.8970 - val_loss: 0.6885 - val_accuracy: 0.8510
#
# Epoch 00062: val_accuracy did not improve from 0.86070
# Epoch 63/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4984 - accuracy: 0.8991 - val_loss: 0.7037 - val_accuracy: 0.8387
#
# Epoch 00063: val_accuracy did not improve from 0.86070
# Epoch 64/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5115 - accuracy: 0.8965 - val_loss: 0.7155 - val_accuracy: 0.8332
#
# Epoch 00064: val_accuracy did not improve from 0.86070
# Epoch 65/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5011 - accuracy: 0.8966 - val_loss: 0.6356 - val_accuracy: 0.8601
#
# Epoch 00065: val_accuracy did not improve from 0.86070
# Epoch 66/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5012 - accuracy: 0.8988 - val_loss: 0.6312 - val_accuracy: 0.8630
#
# Epoch 00066: val_accuracy improved from 0.86070 to 0.86300, saving model to /content/saved_models/cifar10_ResNet20v1_model.066.h5
# Epoch 67/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4929 - accuracy: 0.9017 - val_loss: 0.6366 - val_accuracy: 0.8594
#
# Epoch 00067: val_accuracy did not improve from 0.86300
# Epoch 68/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4934 - accuracy: 0.9016 - val_loss: 0.7238 - val_accuracy: 0.8418
#
# Epoch 00068: val_accuracy did not improve from 0.86300
# Epoch 69/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.4970 - accuracy: 0.8996 - val_loss: 0.6414 - val_accuracy: 0.8617
#
# Epoch 00069: val_accuracy did not improve from 0.86300
# Epoch 70/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.4916 - accuracy: 0.9026 - val_loss: 0.8731 - val_accuracy: 0.8148
#
# Epoch 00070: val_accuracy did not improve from 0.86300
# Epoch 71/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5003 - accuracy: 0.8983 - val_loss: 0.6462 - val_accuracy: 0.8591
#
# Epoch 00071: val_accuracy did not improve from 0.86300
# Epoch 72/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4910 - accuracy: 0.9022 - val_loss: 0.6725 - val_accuracy: 0.8481
#
# Epoch 00072: val_accuracy did not improve from 0.86300
# Epoch 73/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4879 - accuracy: 0.9043 - val_loss: 0.7073 - val_accuracy: 0.8408
#
# Epoch 00073: val_accuracy did not improve from 0.86300
# Epoch 74/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4896 - accuracy: 0.9031 - val_loss: 0.8170 - val_accuracy: 0.8152
#
# Epoch 00074: val_accuracy did not improve from 0.86300
# Epoch 75/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4966 - accuracy: 0.9013 - val_loss: 0.6048 - val_accuracy: 0.8667
#
# Epoch 00075: val_accuracy improved from 0.86300 to 0.86670, saving model to /content/saved_models/cifar10_ResNet20v1_model.075.h5
# Epoch 76/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.4825 - accuracy: 0.9071 - val_loss: 0.6786 - val_accuracy: 0.8504
#
# Epoch 00076: val_accuracy did not improve from 0.86670
# Epoch 77/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4815 - accuracy: 0.9050 - val_loss: 0.6592 - val_accuracy: 0.8576
#
# Epoch 00077: val_accuracy did not improve from 0.86670
# Epoch 78/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4868 - accuracy: 0.9023 - val_loss: 0.7100 - val_accuracy: 0.8465
#
# Epoch 00078: val_accuracy did not improve from 0.86670
# Epoch 79/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.4854 - accuracy: 0.9046 - val_loss: 0.6763 - val_accuracy: 0.8526
#
# Epoch 00079: val_accuracy did not improve from 0.86670
# Epoch 80/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4877 - accuracy: 0.9027 - val_loss: 0.5965 - val_accuracy: 0.8713
#
# Epoch 00080: val_accuracy improved from 0.86670 to 0.87130, saving model to /content/saved_models/cifar10_ResNet20v1_model.080.h5
# Epoch 81/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4873 - accuracy: 0.9041 - val_loss: 0.7943 - val_accuracy: 0.8134
#
# Epoch 00081: val_accuracy did not improve from 0.87130
# Epoch 82/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.4248 - accuracy: 0.9261 - val_loss: 0.5099 - val_accuracy: 0.8982
#
# Epoch 00082: val_accuracy improved from 0.87130 to 0.89820, saving model to /content/saved_models/cifar10_ResNet20v1_model.082.h5
# Epoch 83/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.3771 - accuracy: 0.9421 - val_loss: 0.4997 - val_accuracy: 0.9013
#
# Epoch 00083: val_accuracy improved from 0.89820 to 0.90130, saving model to /content/saved_models/cifar10_ResNet20v1_model.083.h5
# Epoch 84/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.3654 - accuracy: 0.9425 - val_loss: 0.4838 - val_accuracy: 0.9054
#
# Epoch 00084: val_accuracy improved from 0.90130 to 0.90540, saving model to /content/saved_models/cifar10_ResNet20v1_model.084.h5
# Epoch 85/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.3477 - accuracy: 0.9483 - val_loss: 0.4828 - val_accuracy: 0.9065
#
# Epoch 00085: val_accuracy improved from 0.90540 to 0.90650, saving model to /content/saved_models/cifar10_ResNet20v1_model.085.h5
# Epoch 86/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.3380 - accuracy: 0.9501 - val_loss: 0.4787 - val_accuracy: 0.9093
#
# Epoch 00086: val_accuracy improved from 0.90650 to 0.90930, saving model to /content/saved_models/cifar10_ResNet20v1_model.086.h5
# Epoch 87/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.3301 - accuracy: 0.9512 - val_loss: 0.4797 - val_accuracy: 0.9081
#
# Epoch 00087: val_accuracy did not improve from 0.90930
# Epoch 88/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.3220 - accuracy: 0.9533 - val_loss: 0.4683 - val_accuracy: 0.9096
#
# Epoch 00088: val_accuracy improved from 0.90930 to 0.90960, saving model to /content/saved_models/cifar10_ResNet20v1_model.088.h5
# Epoch 89/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.3167 - accuracy: 0.9534 - val_loss: 0.4676 - val_accuracy: 0.9094
#
# Epoch 00089: val_accuracy did not improve from 0.90960
# Epoch 90/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.3062 - accuracy: 0.9577 - val_loss: 0.4657 - val_accuracy: 0.9085
#
# Epoch 00090: val_accuracy did not improve from 0.90960
# Epoch 91/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2999 - accuracy: 0.9565 - val_loss: 0.4655 - val_accuracy: 0.9122
#
# Epoch 00091: val_accuracy improved from 0.90960 to 0.91220, saving model to /content/saved_models/cifar10_ResNet20v1_model.091.h5
# Epoch 92/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.3000 - accuracy: 0.9563 - val_loss: 0.4754 - val_accuracy: 0.9073
#
# Epoch 00092: val_accuracy did not improve from 0.91220
# Epoch 93/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2897 - accuracy: 0.9601 - val_loss: 0.4591 - val_accuracy: 0.9091
#
# Epoch 00093: val_accuracy did not improve from 0.91220
# Epoch 94/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.2857 - accuracy: 0.9591 - val_loss: 0.4623 - val_accuracy: 0.9083
#
# Epoch 00094: val_accuracy did not improve from 0.91220
# Epoch 95/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.2811 - accuracy: 0.9615 - val_loss: 0.4550 - val_accuracy: 0.9118
#
# Epoch 00095: val_accuracy did not improve from 0.91220
# Epoch 96/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2826 - accuracy: 0.9613 - val_loss: 0.4662 - val_accuracy: 0.9071
#
# Epoch 00096: val_accuracy did not improve from 0.91220
# Epoch 97/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.2746 - accuracy: 0.9619 - val_loss: 0.4564 - val_accuracy: 0.9116
#
# Epoch 00097: val_accuracy did not improve from 0.91220
# Epoch 98/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.2653 - accuracy: 0.9646 - val_loss: 0.4558 - val_accuracy: 0.9090
#
# Epoch 00098: val_accuracy did not improve from 0.91220
# Epoch 99/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2594 - accuracy: 0.9650 - val_loss: 0.4495 - val_accuracy: 0.9093
#
# Epoch 00099: val_accuracy did not improve from 0.91220
# Epoch 100/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2628 - accuracy: 0.9644 - val_loss: 0.4579 - val_accuracy: 0.9089
#
# Epoch 00100: val_accuracy did not improve from 0.91220
# Epoch 101/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.2536 - accuracy: 0.9672 - val_loss: 0.4540 - val_accuracy: 0.9084
#
# Epoch 00101: val_accuracy did not improve from 0.91220
# Epoch 102/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2560 - accuracy: 0.9655 - val_loss: 0.4544 - val_accuracy: 0.9099
#
# Epoch 00102: val_accuracy did not improve from 0.91220
# Epoch 103/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2545 - accuracy: 0.9645 - val_loss: 0.4476 - val_accuracy: 0.9108
#
# Epoch 00103: val_accuracy did not improve from 0.91220
# Epoch 104/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2473 - accuracy: 0.9672 - val_loss: 0.4690 - val_accuracy: 0.9066
#
# Epoch 00104: val_accuracy did not improve from 0.91220
# Epoch 105/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.2422 - accuracy: 0.9680 - val_loss: 0.4482 - val_accuracy: 0.9122
#
# Epoch 00105: val_accuracy did not improve from 0.91220
# Epoch 106/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2423 - accuracy: 0.9683 - val_loss: 0.4633 - val_accuracy: 0.9095
#
# Epoch 00106: val_accuracy did not improve from 0.91220
# Epoch 107/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.2386 - accuracy: 0.9670 - val_loss: 0.4579 - val_accuracy: 0.9084
#
# Epoch 00107: val_accuracy did not improve from 0.91220
# Epoch 108/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2373 - accuracy: 0.9693 - val_loss: 0.4534 - val_accuracy: 0.9102
#
# Epoch 00108: val_accuracy did not improve from 0.91220
# Epoch 109/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2282 - accuracy: 0.9713 - val_loss: 0.4561 - val_accuracy: 0.9098
#
# Epoch 00109: val_accuracy did not improve from 0.91220
# Epoch 110/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2264 - accuracy: 0.9713 - val_loss: 0.4522 - val_accuracy: 0.9094
#
# Epoch 00110: val_accuracy did not improve from 0.91220
# Epoch 111/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2284 - accuracy: 0.9694 - val_loss: 0.4451 - val_accuracy: 0.9083
#
# Epoch 00111: val_accuracy did not improve from 0.91220
# Epoch 112/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2274 - accuracy: 0.9700 - val_loss: 0.4580 - val_accuracy: 0.9081
#
# Epoch 00112: val_accuracy did not improve from 0.91220
# Epoch 113/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2208 - accuracy: 0.9716 - val_loss: 0.4711 - val_accuracy: 0.9054
#
# Epoch 00113: val_accuracy did not improve from 0.91220
# Epoch 114/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2185 - accuracy: 0.9727 - val_loss: 0.4554 - val_accuracy: 0.9080
#
# Epoch 00114: val_accuracy did not improve from 0.91220
# Epoch 115/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2190 - accuracy: 0.9704 - val_loss: 0.4558 - val_accuracy: 0.9072
#
# Epoch 00115: val_accuracy did not improve from 0.91220
# Epoch 116/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2154 - accuracy: 0.9725 - val_loss: 0.4662 - val_accuracy: 0.9075
#
# Epoch 00116: val_accuracy did not improve from 0.91220
# Epoch 117/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.2132 - accuracy: 0.9730 - val_loss: 0.4617 - val_accuracy: 0.9059
#
# Epoch 00117: val_accuracy did not improve from 0.91220
# Epoch 118/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2092 - accuracy: 0.9732 - val_loss: 0.4551 - val_accuracy: 0.9085
#
# Epoch 00118: val_accuracy did not improve from 0.91220
# Epoch 119/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2090 - accuracy: 0.9730 - val_loss: 0.4527 - val_accuracy: 0.9092
#
# Epoch 00119: val_accuracy did not improve from 0.91220
# Epoch 120/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2025 - accuracy: 0.9753 - val_loss: 0.4662 - val_accuracy: 0.9047
#
# Epoch 00120: val_accuracy did not improve from 0.91220
# Epoch 121/200
# Learning rate:  0.0001
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.2060 - accuracy: 0.9721 - val_loss: 0.4590 - val_accuracy: 0.9090
#
# Epoch 00121: val_accuracy did not improve from 0.91220
# Epoch 122/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1942 - accuracy: 0.9775 - val_loss: 0.4388 - val_accuracy: 0.9103
#
# Epoch 00122: val_accuracy did not improve from 0.91220
# Epoch 123/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1937 - accuracy: 0.9781 - val_loss: 0.4371 - val_accuracy: 0.9096
#
# Epoch 00123: val_accuracy did not improve from 0.91220
# Epoch 124/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1928 - accuracy: 0.9780 - val_loss: 0.4379 - val_accuracy: 0.9098
#
# Epoch 00124: val_accuracy did not improve from 0.91220
# Epoch 125/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.1901 - accuracy: 0.9785 - val_loss: 0.4368 - val_accuracy: 0.9103
#
# Epoch 00125: val_accuracy did not improve from 0.91220
# Epoch 126/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1901 - accuracy: 0.9782 - val_loss: 0.4378 - val_accuracy: 0.9095
#
# Epoch 00126: val_accuracy did not improve from 0.91220
# Epoch 127/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.1884 - accuracy: 0.9788 - val_loss: 0.4357 - val_accuracy: 0.9104
#
# Epoch 00127: val_accuracy did not improve from 0.91220
# Epoch 128/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1903 - accuracy: 0.9781 - val_loss: 0.4381 - val_accuracy: 0.9098
#
# Epoch 00128: val_accuracy did not improve from 0.91220
# Epoch 129/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1839 - accuracy: 0.9806 - val_loss: 0.4364 - val_accuracy: 0.9090
#
# Epoch 00129: val_accuracy did not improve from 0.91220
# Epoch 130/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1878 - accuracy: 0.9789 - val_loss: 0.4373 - val_accuracy: 0.9115
#
# Epoch 00130: val_accuracy did not improve from 0.91220
# Epoch 131/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.1839 - accuracy: 0.9808 - val_loss: 0.4385 - val_accuracy: 0.9100
#
# Epoch 00131: val_accuracy did not improve from 0.91220
# Epoch 132/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1834 - accuracy: 0.9817 - val_loss: 0.4366 - val_accuracy: 0.9094
#
# Epoch 00132: val_accuracy did not improve from 0.91220
# Epoch 133/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1822 - accuracy: 0.9815 - val_loss: 0.4398 - val_accuracy: 0.9095
#
# Epoch 00133: val_accuracy did not improve from 0.91220
# Epoch 134/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1840 - accuracy: 0.9809 - val_loss: 0.4376 - val_accuracy: 0.9089
#
# Epoch 00134: val_accuracy did not improve from 0.91220
# Epoch 135/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1818 - accuracy: 0.9813 - val_loss: 0.4393 - val_accuracy: 0.9080
#
# Epoch 00135: val_accuracy did not improve from 0.91220
# Epoch 136/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1803 - accuracy: 0.9826 - val_loss: 0.4390 - val_accuracy: 0.9093
#
# Epoch 00136: val_accuracy did not improve from 0.91220
# Epoch 137/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1827 - accuracy: 0.9813 - val_loss: 0.4408 - val_accuracy: 0.9092
#
# Epoch 00137: val_accuracy did not improve from 0.91220
# Epoch 138/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1817 - accuracy: 0.9816 - val_loss: 0.4423 - val_accuracy: 0.9081
#
# Epoch 00138: val_accuracy did not improve from 0.91220
# Epoch 139/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1818 - accuracy: 0.9819 - val_loss: 0.4398 - val_accuracy: 0.9096
#
# Epoch 00139: val_accuracy did not improve from 0.91220
# Epoch 140/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1807 - accuracy: 0.9824 - val_loss: 0.4391 - val_accuracy: 0.9105
#
# Epoch 00140: val_accuracy did not improve from 0.91220
# Epoch 141/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1814 - accuracy: 0.9814 - val_loss: 0.4419 - val_accuracy: 0.9099
#
# Epoch 00141: val_accuracy did not improve from 0.91220
# Epoch 142/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1808 - accuracy: 0.9820 - val_loss: 0.4403 - val_accuracy: 0.9082
#
# Epoch 00142: val_accuracy did not improve from 0.91220
# Epoch 143/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1782 - accuracy: 0.9834 - val_loss: 0.4408 - val_accuracy: 0.9101
#
# Epoch 00143: val_accuracy did not improve from 0.91220
# Epoch 144/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1795 - accuracy: 0.9825 - val_loss: 0.4408 - val_accuracy: 0.9087
#
# Epoch 00144: val_accuracy did not improve from 0.91220
# Epoch 145/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1770 - accuracy: 0.9837 - val_loss: 0.4405 - val_accuracy: 0.9089
#
# Epoch 00145: val_accuracy did not improve from 0.91220
# Epoch 146/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1792 - accuracy: 0.9824 - val_loss: 0.4424 - val_accuracy: 0.9087
#
# Epoch 00146: val_accuracy did not improve from 0.91220
# Epoch 147/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1772 - accuracy: 0.9828 - val_loss: 0.4414 - val_accuracy: 0.9098
#
# Epoch 00147: val_accuracy did not improve from 0.91220
# Epoch 148/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1766 - accuracy: 0.9834 - val_loss: 0.4409 - val_accuracy: 0.9103
#
# Epoch 00148: val_accuracy did not improve from 0.91220
# Epoch 149/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1769 - accuracy: 0.9838 - val_loss: 0.4391 - val_accuracy: 0.9092
#
# Epoch 00149: val_accuracy did not improve from 0.91220
# Epoch 150/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1778 - accuracy: 0.9824 - val_loss: 0.4420 - val_accuracy: 0.9090
#
# Epoch 00150: val_accuracy did not improve from 0.91220
# Epoch 151/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1769 - accuracy: 0.9829 - val_loss: 0.4394 - val_accuracy: 0.9104
#
# Epoch 00151: val_accuracy did not improve from 0.91220
# Epoch 152/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1768 - accuracy: 0.9827 - val_loss: 0.4395 - val_accuracy: 0.9106
#
# Epoch 00152: val_accuracy did not improve from 0.91220
# Epoch 153/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1761 - accuracy: 0.9839 - val_loss: 0.4401 - val_accuracy: 0.9112
#
# Epoch 00153: val_accuracy did not improve from 0.91220
# Epoch 154/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1751 - accuracy: 0.9830 - val_loss: 0.4424 - val_accuracy: 0.9102
#
# Epoch 00154: val_accuracy did not improve from 0.91220
# Epoch 155/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1757 - accuracy: 0.9821 - val_loss: 0.4418 - val_accuracy: 0.9103
#
# Epoch 00155: val_accuracy did not improve from 0.91220
# Epoch 156/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1739 - accuracy: 0.9832 - val_loss: 0.4424 - val_accuracy: 0.9106
#
# Epoch 00156: val_accuracy did not improve from 0.91220
# Epoch 157/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1749 - accuracy: 0.9835 - val_loss: 0.4418 - val_accuracy: 0.9113
#
# Epoch 00157: val_accuracy did not improve from 0.91220
# Epoch 158/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1713 - accuracy: 0.9849 - val_loss: 0.4458 - val_accuracy: 0.9109
#
# Epoch 00158: val_accuracy did not improve from 0.91220
# Epoch 159/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1776 - accuracy: 0.9808 - val_loss: 0.4450 - val_accuracy: 0.9101
#
# Epoch 00159: val_accuracy did not improve from 0.91220
# Epoch 160/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1730 - accuracy: 0.9831 - val_loss: 0.4437 - val_accuracy: 0.9114
#
# Epoch 00160: val_accuracy did not improve from 0.91220
# Epoch 161/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1720 - accuracy: 0.9841 - val_loss: 0.4452 - val_accuracy: 0.9102
#
# Epoch 00161: val_accuracy did not improve from 0.91220
# Epoch 162/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1730 - accuracy: 0.9841 - val_loss: 0.4447 - val_accuracy: 0.9094
#
# Epoch 00162: val_accuracy did not improve from 0.91220
# Epoch 163/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1730 - accuracy: 0.9843 - val_loss: 0.4435 - val_accuracy: 0.9105
#
# Epoch 00163: val_accuracy did not improve from 0.91220
# Epoch 164/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1718 - accuracy: 0.9836 - val_loss: 0.4443 - val_accuracy: 0.9108
#
# Epoch 00164: val_accuracy did not improve from 0.91220
# Epoch 165/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1733 - accuracy: 0.9835 - val_loss: 0.4447 - val_accuracy: 0.9113
#
# Epoch 00165: val_accuracy did not improve from 0.91220
# Epoch 166/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1718 - accuracy: 0.9843 - val_loss: 0.4442 - val_accuracy: 0.9101
#
# Epoch 00166: val_accuracy did not improve from 0.91220
# Epoch 167/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1716 - accuracy: 0.9844 - val_loss: 0.4433 - val_accuracy: 0.9107
#
# Epoch 00167: val_accuracy did not improve from 0.91220
# Epoch 168/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1740 - accuracy: 0.9830 - val_loss: 0.4441 - val_accuracy: 0.9111
#
# Epoch 00168: val_accuracy did not improve from 0.91220
# Epoch 169/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1703 - accuracy: 0.9849 - val_loss: 0.4436 - val_accuracy: 0.9107
#
# Epoch 00169: val_accuracy did not improve from 0.91220
# Epoch 170/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1731 - accuracy: 0.9828 - val_loss: 0.4429 - val_accuracy: 0.9106
#
# Epoch 00170: val_accuracy did not improve from 0.91220
# Epoch 171/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1737 - accuracy: 0.9837 - val_loss: 0.4451 - val_accuracy: 0.9100
#
# Epoch 00171: val_accuracy did not improve from 0.91220
# Epoch 172/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1723 - accuracy: 0.9842 - val_loss: 0.4447 - val_accuracy: 0.9097
#
# Epoch 00172: val_accuracy did not improve from 0.91220
# Epoch 173/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1720 - accuracy: 0.9846 - val_loss: 0.4441 - val_accuracy: 0.9108
#
# Epoch 00173: val_accuracy did not improve from 0.91220
# Epoch 174/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1738 - accuracy: 0.9835 - val_loss: 0.4453 - val_accuracy: 0.9100
#
# Epoch 00174: val_accuracy did not improve from 0.91220
# Epoch 175/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1709 - accuracy: 0.9842 - val_loss: 0.4439 - val_accuracy: 0.9109
#
# Epoch 00175: val_accuracy did not improve from 0.91220
# Epoch 176/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1745 - accuracy: 0.9831 - val_loss: 0.4445 - val_accuracy: 0.9109
#
# Epoch 00176: val_accuracy did not improve from 0.91220
# Epoch 177/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1707 - accuracy: 0.9841 - val_loss: 0.4433 - val_accuracy: 0.9110
#
# Epoch 00177: val_accuracy did not improve from 0.91220
# Epoch 178/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1710 - accuracy: 0.9844 - val_loss: 0.4439 - val_accuracy: 0.9111
#
# Epoch 00178: val_accuracy did not improve from 0.91220
# Epoch 179/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 27ms/step - loss: 0.1713 - accuracy: 0.9831 - val_loss: 0.4447 - val_accuracy: 0.9106
#
# Epoch 00179: val_accuracy did not improve from 0.91220
# Epoch 180/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 27ms/step - loss: 0.1711 - accuracy: 0.9835 - val_loss: 0.4443 - val_accuracy: 0.9110
#
# Epoch 00180: val_accuracy did not improve from 0.91220
# Epoch 181/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1712 - accuracy: 0.9834 - val_loss: 0.4433 - val_accuracy: 0.9114
#
# Epoch 00181: val_accuracy did not improve from 0.91220
# Epoch 182/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1722 - accuracy: 0.9836 - val_loss: 0.4442 - val_accuracy: 0.9102
#
# Epoch 00182: val_accuracy did not improve from 0.91220
# Epoch 183/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1720 - accuracy: 0.9838 - val_loss: 0.4448 - val_accuracy: 0.9108
#
# Epoch 00183: val_accuracy did not improve from 0.91220
# Epoch 184/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1729 - accuracy: 0.9834 - val_loss: 0.4451 - val_accuracy: 0.9103
#
# Epoch 00184: val_accuracy did not improve from 0.91220
# Epoch 185/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1749 - accuracy: 0.9824 - val_loss: 0.4443 - val_accuracy: 0.9109
#
# Epoch 00185: val_accuracy did not improve from 0.91220
# Epoch 186/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1728 - accuracy: 0.9834 - val_loss: 0.4445 - val_accuracy: 0.9107
#
# Epoch 00186: val_accuracy did not improve from 0.91220
# Epoch 187/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1726 - accuracy: 0.9831 - val_loss: 0.4444 - val_accuracy: 0.9104
#
# Epoch 00187: val_accuracy did not improve from 0.91220
# Epoch 188/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1697 - accuracy: 0.9845 - val_loss: 0.4439 - val_accuracy: 0.9113
#
# Epoch 00188: val_accuracy did not improve from 0.91220
# Epoch 189/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1741 - accuracy: 0.9830 - val_loss: 0.4440 - val_accuracy: 0.9108
#
# Epoch 00189: val_accuracy did not improve from 0.91220
# Epoch 190/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1711 - accuracy: 0.9844 - val_loss: 0.4450 - val_accuracy: 0.9109
#
# Epoch 00190: val_accuracy did not improve from 0.91220
# Epoch 191/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1698 - accuracy: 0.9844 - val_loss: 0.4441 - val_accuracy: 0.9106
#
# Epoch 00191: val_accuracy did not improve from 0.91220
# Epoch 192/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1715 - accuracy: 0.9848 - val_loss: 0.4428 - val_accuracy: 0.9104
#
# Epoch 00192: val_accuracy did not improve from 0.91220
# Epoch 193/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1720 - accuracy: 0.9836 - val_loss: 0.4444 - val_accuracy: 0.9106
#
# Epoch 00193: val_accuracy did not improve from 0.91220
# Epoch 194/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1723 - accuracy: 0.9838 - val_loss: 0.4439 - val_accuracy: 0.9107
#
# Epoch 00194: val_accuracy did not improve from 0.91220
# Epoch 195/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1710 - accuracy: 0.9840 - val_loss: 0.4426 - val_accuracy: 0.9108
#
# Epoch 00195: val_accuracy did not improve from 0.91220
# Epoch 196/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1724 - accuracy: 0.9836 - val_loss: 0.4438 - val_accuracy: 0.9108
#
# Epoch 00196: val_accuracy did not improve from 0.91220
# Epoch 197/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1682 - accuracy: 0.9857 - val_loss: 0.4428 - val_accuracy: 0.9107
#
# Epoch 00197: val_accuracy did not improve from 0.91220
# Epoch 198/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.1700 - accuracy: 0.9850 - val_loss: 0.4438 - val_accuracy: 0.9107
#
# Epoch 00198: val_accuracy did not improve from 0.91220
# Epoch 199/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 41s 27ms/step - loss: 0.1695 - accuracy: 0.9849 - val_loss: 0.4430 - val_accuracy: 0.9103
#
# Epoch 00199: val_accuracy did not improve from 0.91220
# Epoch 200/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.1706 - accuracy: 0.9850 - val_loss: 0.4419 - val_accuracy: 0.9110
#
# Epoch 00200: val_accuracy did not improve from 0.91220

# %%
#0.91220

# %%
def summarize_diagnostics(history):
	# plot loss
	pyplot.subplot(211)
	pyplot.title('Cross Entropy Loss')
	pyplot.plot(history.history['loss'], color='blue', label='train')
	pyplot.plot(history.history['val_loss'], color='orange', label='test')
	# plot accuracy
	pyplot.subplot(212)
	pyplot.title('Classification Accuracy')
	pyplot.plot(history.history['accuracy'], color='blue', label='train')
	pyplot.plot(history.history['val_accuracy'], color='orange', label='test')
	# save plot to file
	filename = sys.argv[0].split('/')[-1]
	pyplot.savefig(filename + '_plot.png')
	pyplot.close()
